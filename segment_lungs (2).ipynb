# %%
import os
import torch
import numpy as np
import numpy as np
from segment_anything import sam_model_registry, SamPredictor
import matplotlib.pyplot as plt
import cv2
import torch
import xml.etree.ElementTree as ET

# %%
# !wget -q 'https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth'

# %%
SAM_CHECKPOINT_PATH = os.path.join("weights", "sam_vit_h_4b8939.pth")
SAM_ENCODER_VERSION = "vit_h"
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(DEVICE)
XML_NAME = os.path.join("groundtruth", "tb_lungs.xml")
# Out:
# cuda

# %%
class SAM:
    def __init__(self):
        self.predictor = self._initialize_predictor()

    def _initialize_predictor(self):
        sam = sam_model_registry[SAM_ENCODER_VERSION](checkpoint=SAM_CHECKPOINT_PATH).to(device=DEVICE)
        return SamPredictor(sam)

    def set_image(self, image: np.ndarray):
        self.predictor.set_image(image)

    def segment_no_jitter(self, image: np.ndarray, xyxy: np.ndarray) -> np.ndarray:
        self.set_image(image)
        result_masks = []
        for box in xyxy:
            masks, scores, logits = self.predictor.predict(
                box=box,
                multimask_output=True
            )
            index = np.argmax(scores)
            result_masks.append(masks[index])
        result_array = np.array(result_masks)
        print('made it ')
        return {'left': np.transpose(np.nonzero(result_array[0])),
                'right': np.transpose(np.nonzero(result_array[1]))
                },  {'left': result_array[0],
                'right':  result_array[1]}



    # helper functions to show mask and box for SAM display
    @staticmethod
    def show_mask(mask, plt, color, random_color=False):
        if random_color:
            color = np.concatenate([np.random.random(3), np.array([0.4])], axis=0)
        h, w = mask.shape[-2:]
        mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
        plt.imshow(mask_image)

    @staticmethod
    #display the bounding box on the plot
    def show_box(box, ax):
        x0, y0 = box[0], box[1]
        w, h = box[2] - box[0], box[3] - box[1]
        ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))

# %%
def extract_rle_from_xml(xml_file_path, image_name, structure):
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Iterate through all 'image' elements in the XML
    for image in root.findall('image'):
        if image.get('name') == image_name:
            width = int(image.get('width'))
            height = int(image.get('height'))


            # If the image name matches, search for the structure
            for mask in image.findall('mask'):
                if mask.get('label') == structure:
                    mask_top = int(mask.get('top'))
                    mask_width = int(mask.get('width'))
                    mask_left = int(mask.get('left'))
                    return mask.get('rle'), width, height, mask_top, mask_width,mask_left
    return None


def cvat_rle_to_binary_image_mask(rle, left, top, width, img_h, img_w):
    # convert CVAT tight object RLE to COCO-style whole image mask
    rle = [int(x) for x in rle.split(',')]

    mask = np.zeros((img_h, img_w), dtype=np.uint8)
    value = 0
    offset = 0
    for rle_count in rle:
        while rle_count > 0:
            y, x = divmod(offset, width)
            mask[y + top][x + left] = value
            rle_count -= 1
            offset += 1
        value = 1 - value

    return mask

# %%
def dice_coefficient(mask1, mask2):
    """
    Calculate the Dice similarity coefficient between two masks.

    Parameters:
    - mask1: a binary 2D array (ground truth mask)
    - mask2: a binary 2D array (predicted mask)

    Returns:
    - dice: Dice coefficient as a float
    """
    # Flatten the masks
    mask1 = mask1.flatten()
    mask2 = mask2.flatten()

    # Calculate intersection and sum of pixels for each mask
    intersection = np.sum(mask1 * mask2)
    total_pixels_mask1 = np.sum(mask1)
    total_pixels_mask2 = np.sum(mask2)

    # Calculate the Dice coefficient
    dice = (2. * intersection) / (total_pixels_mask1 + total_pixels_mask2)

    return dice

# %%
def calculate_lung_bounding_boxes(image_shape, offset_factor=0.05, top_margin_factor=0.15):
    """
    Calculate bounding boxes for the left and right lung areas.

    Inputs:
    - image_shape: The shape of the image as (height, width).
    - offset_factor: How far from the midline the boxes start, as a fraction of the image width.
    - top_margin_factor: How far down from the top of the image the boxes start, as a fraction of the image height.

    Returns:
    - A tuple containing the bounding box for the left lung and the right lung.
      Each box is represented as [x_min, y_min, x_max, y_max].
    """
    height, width = image_shape
    box_width = width // 4
    box_height = height // 1.4

    midline = width // 2
    offset = int(width * offset_factor)
    top_margin = int(height * top_margin_factor)

    left_box = np.array([midline - box_width - offset, top_margin, midline - offset, top_margin + box_height])
    right_box = np.array([midline + offset, top_margin, midline + box_width + offset, top_margin + box_height])

    return  right_box, left_box

# %%
def evaluation_engine():
  sam = SAM()
  left_dice_score = []
  right_dice_score = []
  DATA = '/content/tb_annotated'
  for root, dirs,files in os.walk(DATA):
      for idx, file in enumerate(files):
          print(idx, file)
          if file.endswith('.png') or file.endswith('.JPG') or file.endswith('.jpeg') and 'checkpoint' not in file:
          # try:
              image_name = (os.path.join(root, file))
              image = cv2.imread(image_name)
              #file=file[:-4]

              left_box, right_box = calculate_lung_bounding_boxes(image.shape[:2])
              detections_masks_dict, detections_array_dict = sam.segment_no_jitter(image, [left_box, right_box])

              # Plotting
              fig, ax = plt.subplots(1)
              ax.imshow(image)  # Display the original image

              # Plot the masks and bounding boxes
              for box, mask in zip([left_box, right_box], ['left', 'right']):
                  mask_image = detections_array_dict[mask]
                  ax.imshow(mask_image, cmap='jet', alpha=0.3)  # Overlay the mask with some transparency
                  SAM.show_box(box, ax)  # Show the bounding box

              # Display the plot
              plt.title(f"Segmentation and Bounding Box for {file}")
              plt.show()

              gt_structures = ['left_lung', 'right_lung']
              ground_truth_name = file

              xml_file_path = XML_NAME

              # extract masks from ground truth rle file
              binary_masks = []
              for gt_struct in gt_structures:
                  rle, width, height, top, mask_width, mask_left = extract_rle_from_xml(xml_file_path, ground_truth_name, gt_struct)
                  print(rle)
                  # compute binary mask from rle
                  mask = cvat_rle_to_binary_image_mask(rle, mask_left, top, mask_width, height, width)
                  plt.imshow(mask)
                  plt.show()
                  binary_masks.append(mask)

              left_dice = dice_coefficient(binary_masks[0], detections_array_dict['left'])
              right_dice = dice_coefficient(binary_masks[1], detections_array_dict['right'])
              left_dice_score.append(left_dice)
              right_dice_score.append(right_dice)
  # Data preparation for plotting
  data = [left_dice_score, right_dice_score]
  labels = ['Left Lung', 'Right Lung']

  # Create box plots
  plt.figure(figsize=(10, 6))
  plt.boxplot(data, labels=labels)

  # Adding title and labels
  plt.title('Dice Scores for Left and Right Lungs')
  plt.ylabel('Dice Score')

  # Show the plot
  plt.show()

# evaluation_engine()

# %%
sam = SAM()

# %%
def resize_image_with_padding(img, desired_size=500):
    # Compute the new size, maintaining the aspect ratio
    ratio = float(desired_size) / max(img.shape)
    new_size = tuple([int(x * ratio) for x in img.shape[1::-1]])

    # Resize the image
    resized_img = cv2.resize(img, new_size, interpolation=cv2.INTER_AREA)

    # Create a new image and place the resized image into the center
    new_img = np.zeros((desired_size, desired_size, img.shape[2]), dtype=np.uint8)
    x_offset = (desired_size - new_size[0]) // 2
    y_offset = (desired_size - new_size[1]) // 2
    new_img[y_offset:y_offset+new_size[1], x_offset:x_offset+new_size[0]] = resized_img

    return new_img

# %%
def store_masked_images():
    DATA = 'all_data'
    output_dir = 'contrast_then_sam'
    # os.makedirs(output_dir, exist_ok=True)

    for root, dirs, files in os.walk(DATA):
        for idx, file in enumerate(files):
            if file.endswith(('.png', '.jpg', '.jpeg')) and 'checkpoint' not in file:
                print(idx, file)
                image_name = os.path.join(root, file)
                
                image = cv2.imread(image_name)


                image = cv2.cvtColor(image, cv2.COLOR_RGB2Lab)
            
                # Split the Lab image into its channels
                l_channel, a_channel, b_channel = cv2.split(image)
            
                # Create a CLAHE object
                clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
            
                # Apply CLAHE to the L channel
                l_channel_clahe = clahe.apply(l_channel)
            
                # Merge the CLAHE enhanced L channel back with A and B channels
                lab_image_clahe = cv2.merge((l_channel_clahe, a_channel, b_channel))
            
                # Convert back to RGB color space
                image = cv2.cvtColor(lab_image_clahe, cv2.COLOR_Lab2RGB)

                
                left_box, right_box = calculate_lung_bounding_boxes(image.shape[:2])
                detections_masks_dict, detections_array_dict = sam.segment_no_jitter(image, [left_box, right_box])

                # Assuming masks are binary and of the same dimensions as the image
                left_mask = detections_array_dict['left']
                right_mask = detections_array_dict['right']

                # Find the most medial pixels for each lung
                left_medial_x = np.min(np.where(left_mask)[1])
                right_medial_x = np.max(np.where(right_mask)[1])

                # Calculate distance to move left lung mask
                distance_to_move = right_medial_x - left_medial_x - 1

                # Shift left lung mask to the right
                shifted_left_mask = np.roll(left_mask, shift=distance_to_move, axis=1)

                # Combine masks
                combined_mask = np.logical_or(shifted_left_mask, right_mask)
       
                # Find the bounding box of the combined mask
                rows = np.any(combined_mask, axis=1)
                cols = np.any(combined_mask, axis=0)
                ymin, ymax = np.where(rows)[0][[0, -1]]
                xmin, xmax = np.where(cols)[0][[0, -1]]


                # image = cv2.cvtColor(image, cv2.COLOR_RGB2Lab)
            
                # # Split the Lab image into its channels
                # l_channel, a_channel, b_channel = cv2.split(image)
            
                # # Create a CLAHE object
                # clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
            
                # # Apply CLAHE to the L channel
                # l_channel_clahe = clahe.apply(l_channel)
            
                # # Merge the CLAHE enhanced L channel back with A and B channels
                # lab_image_clahe = cv2.merge((l_channel_clahe, a_channel, b_channel))
            
                # # Convert back to RGB color space
                # image = cv2.cvtColor(lab_image_clahe, cv2.COLOR_Lab2RGB)

                
                # image = cv2.GaussianBlur(image,(51,51),0)

                # Crop the image
                # Create a new blank image and place the lungs within it
                new_image = np.zeros_like(image)
                new_image[ymin:ymax+1, xmin:xmax+1] = image[ymin:ymax+1, xmin:xmax+1] * combined_mask[ymin:ymax+1, xmin:xmax+1, None]
                cropped_image = new_image[ymin:ymax+1, xmin:xmax+1]


                # Add this part to the end of your for loop after you obtain the cropped_image
                # resized_cropped_image = resize_image_with_padding(cropped_image)
                resized_cropped_image = cv2.resize(cropped_image, (500,500))
                # plt.imshow(resized_cropped_image)  # Convert to RGB for displaying
                # # plt.title("Resized Cropped Image")
                # plt.show()

                output_image_path = os.path.join(output_dir, f"lungs_{file}")
                cv2.imwrite(output_image_path, resized_cropped_image)

                # Save the cropped image
                # output_image_path = os.path.join(output_dir, f"cropped_{file}")
                # cv2.imwrite(output_image_path, cropped_image)

                # Optionally display the cropped image
                # fig, ax = plt.subplots(1)
                # ax.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))  # Convert to RGB for displaying
                # plt.title(f"Cropped Segmentation for {file}")
                # plt.show()


# Call the function to process and store masked images
store_masked_images()
# Out:
# 0 CHNCXR_0069_0.png
# made it
# 1 CHNCXR_0470_1.png
# made it
# 2 CHNCXR_0367_1.png
# made it
# 3 CHNCXR_0147_0.png
# made it
# 4 CHNCXR_0174_0.png
# made it
# 5 CHNCXR_0644_1.png
# made it
# 6 CHNCXR_0003_0.png
# made it
# 7 CHNCXR_0454_1.png
# made it
# 8 CHNCXR_0366_1.png
# made it
# 9 CHNCXR_0467_1.png
# made it
# 10 CHNCXR_0616_1.png
# made it
# 11 CHNCXR_0420_1.png
# made it
# 12 CHNCXR_0296_0.png
# made it
# 13 CHNCXR_0010_0.png
# made it
# 14 CHNCXR_0046_0.png
# made it
# 15 CHNCXR_0553_1.png
# made it
# 16 CHNCXR_0086_0.png
# made it
# 17 CHNCXR_0073_0.png
# made it
# 18 CHNCXR_0588_1.png
# made it
# 19 CHNCXR_0517_1.png
# made it
# 20 CHNCXR_0158_0.png
# made it
# 21 CHNCXR_0423_1.png
# made it
# 22 CHNCXR_0061_0.png
# made it
# 23 CHNCXR_0662_1.png
# made it
# 24 CHNCXR_0240_0.png
# made it
# 25 CHNCXR_0625_1.png
# made it
# 26 CHNCXR_0529_1.png
# made it
# 27 CHNCXR_0455_1.png
# made it
# 28 CHNCXR_0409_1.png
# made it
# 29 CHNCXR_0329_1.png
# made it
# 30 CHNCXR_0014_0.png
# made it
# 31 CHNCXR_0276_0.png
# made it
# 32 CHNCXR_0021_0.png
# made it
# 33 CHNCXR_0234_0.png
# made it
# 34 CHNCXR_0229_0.png
# made it
# 35 CHNCXR_0096_0.png
# made it
# 36 CHNCXR_0321_0.png
# made it
# 37 CHNCXR_0109_0.png
# made it
# 38 CHNCXR_0526_1.png
# made it
# 39 CHNCXR_0252_0.png
# made it
# 40 CHNCXR_0374_1.png
# made it
# 41 CHNCXR_0100_0.png
# made it
# 42 CHNCXR_0334_1.png
# made it
# 43 CHNCXR_0377_1.png
# made it
# 44 CHNCXR_0272_0.png
# made it
# 45 CHNCXR_0120_0.png
# made it
# 46 CHNCXR_0577_1.png
# made it
# 47 CHNCXR_0351_1.png
# made it
# 48 CHNCXR_0642_1.png
# made it
# 49 CHNCXR_0089_0.png
# made it
# 50 CHNCXR_0551_1.png
# made it
# 51 CHNCXR_0632_1.png
# made it
# 52 CHNCXR_0285_0.png
# made it
# 53 CHNCXR_0479_1.png
# made it
# 54 CHNCXR_0603_1.png
# made it
# 55 CHNCXR_0392_1.png
# made it
# 56 CHNCXR_0410_1.png
# made it
# 57 CHNCXR_0060_0.png
# made it
# 58 CHNCXR_0637_1.png
# made it
# 59 CHNCXR_0245_0.png
# made it
# 60 CHNCXR_0052_0.png
# made it
# 61 CHNCXR_0491_1.png
# made it
# 62 CHNCXR_0041_0.png
# made it
# 63 CHNCXR_0578_1.png
# made it
# 64 CHNCXR_0064_0.png
# made it
# 65 CHNCXR_0571_1.png
# made it
# 66 CHNCXR_0255_0.png
# made it
# 67 CHNCXR_0450_1.png
# made it
# 68 CHNCXR_0607_1.png
# made it
# 69 CHNCXR_0508_1.png
# made it
# 70 CHNCXR_0012_0.png
# made it
# 71 CHNCXR_0092_0.png
# made it
# 72 CHNCXR_0617_1.png
# made it
# 73 CHNCXR_0159_0.png
# made it
# 74 CHNCXR_0058_0.png
# made it
# 75 CHNCXR_0062_0.png
# made it
# 76 CHNCXR_0097_0.png
# made it
# 77 CHNCXR_0440_1.png
# made it
# 78 CHNCXR_0151_0.png
# made it
# 79 CHNCXR_0499_1.png
# made it
# 80 CHNCXR_0098_0.png
# made it
# 81 CHNCXR_0217_0.png
# made it
# 82 CHNCXR_0404_1.png
# made it
# 83 CHNCXR_0528_1.png
# made it
# 84 CHNCXR_0299_0.png
# made it
# 85 CHNCXR_0443_1.png
# made it
# 86 CHNCXR_0200_0.png
# made it
# 87 CHNCXR_0458_1.png
# made it
# 88 CHNCXR_0237_0.png
# made it
# 89 CHNCXR_0570_1.png
# made it
# 90 CHNCXR_0193_0.png
# made it
# 91 CHNCXR_0340_1.png
# made it
# 92 CHNCXR_0333_1.png
# made it
# 93 CHNCXR_0197_0.png
# made it
# 94 CHNCXR_0091_0.png
# made it
# 95 CHNCXR_0270_0.png
# made it
# 96 CHNCXR_0338_1.png
# made it
# 97 CHNCXR_0142_0.png
# made it
# 98 CHNCXR_0513_1.png
# made it
# 99 CHNCXR_0302_0.png
# made it
# 100 CHNCXR_0093_0.png
# made it
# 101 CHNCXR_0278_0.png
# made it
# 102 CHNCXR_0173_0.png
# made it
# 103 CHNCXR_0383_1.png
# made it
# 104 CHNCXR_0572_1.png
# made it
# 105 CHNCXR_0397_1.png
# made it
# 106 CHNCXR_0031_0.png
# made it
# 107 CHNCXR_0269_0.png
# made it
# 108 CHNCXR_0422_1.png
# made it
# 109 CHNCXR_0414_1.png
# made it
# 110 CHNCXR_0322_0.png
# made it
# 111 CHNCXR_0210_0.png
# made it
# 112 CHNCXR_0661_1.png
# made it
# 113 CHNCXR_0619_1.png
# made it
# 114 CHNCXR_0049_0.png
# made it
# 115 CHNCXR_0001_0.png
# made it
# 116 CHNCXR_0538_1.png
# made it
# 117 CHNCXR_0071_0.png
# made it
# 118 CHNCXR_0286_0.png
# made it
# 119 CHNCXR_0078_0.png
# made it
# 120 CHNCXR_0176_0.png
# made it
# 121 CHNCXR_0427_1.png
# made it
# 122 CHNCXR_0599_1.png
# made it
# 123 CHNCXR_0436_1.png
# made it
# 124 CHNCXR_0066_0.png
# made it
# 125 CHNCXR_0102_0.png
# made it
# 126 CHNCXR_0565_1.png
# made it
# 127 CHNCXR_0504_1.png
# made it
# 128 CHNCXR_0474_1.png
# made it
# 129 CHNCXR_0596_1.png
# made it
# 130 CHNCXR_0506_1.png
# made it
# 131 CHNCXR_0368_1.png
# made it
# 132 CHNCXR_0090_0.png
# made it
# 133 CHNCXR_0581_1.png
# made it
# 134 CHNCXR_0138_0.png
# made it
# 135 CHNCXR_0627_1.png
# made it
# 136 CHNCXR_0394_1.png
# made it
# 137 CHNCXR_0358_1.png
# made it
# 138 CHNCXR_0395_1.png
# made it
# 139 CHNCXR_0250_0.png
# made it
# 140 CHNCXR_0331_1.png
# made it
# 141 CHNCXR_0063_0.png
# made it
# 142 CHNCXR_0618_1.png
# made it
# 143 CHNCXR_0378_1.png
# made it
# 144 CHNCXR_0106_0.png
# made it
# 145 CHNCXR_0256_0.png
# made it
# 146 CHNCXR_0613_1.png
# made it
# 147 CHNCXR_0371_1.png
# made it
# 148 CHNCXR_0600_1.png
# made it
# 149 CHNCXR_0257_0.png
# made it
# 150 CHNCXR_0190_0.png
# made it
# 151 CHNCXR_0527_1.png
# made it
# 152 CHNCXR_0541_1.png
# made it
# 153 CHNCXR_0465_1.png
# made it
# 154 CHNCXR_0028_0.png
# made it
# 155 CHNCXR_0251_0.png
# made it
# 156 CHNCXR_0065_0.png
# made it
# 157 CHNCXR_0610_1.png
# made it
# 158 CHNCXR_0612_1.png
# made it
# 159 CHNCXR_0561_1.png
# made it
# 160 CHNCXR_0398_1.png
# made it
# 161 CHNCXR_0218_0.png
# made it
# 162 CHNCXR_0183_0.png
# made it
# 163 CHNCXR_0024_0.png
# made it
# 164 CHNCXR_0586_1.png
# made it
# 165 CHNCXR_0390_1.png
# made it
# 166 CHNCXR_0580_1.png
# made it
# 167 CHNCXR_0044_0.png
# made it
# 168 CHNCXR_0439_1.png
# made it
# 169 CHNCXR_0546_1.png
# made it
# 170 CHNCXR_0431_1.png
# made it
# 171 CHNCXR_0040_0.png
# made it
# 172 CHNCXR_0460_1.png
# made it
# 173 CHNCXR_0015_0.png
# made it
# 174 CHNCXR_0425_1.png
# made it
# 175 CHNCXR_0125_0.png
# made it
# 176 CHNCXR_0393_1.png
# made it
# 177 CHNCXR_0134_0.png
# made it
# 178 CHNCXR_0236_0.png
# made it
# 179 CHNCXR_0011_0.png
# made it
# 180 CHNCXR_0209_0.png
# made it
# 181 CHNCXR_0601_1.png
# made it
# 182 CHNCXR_0005_0.png
# made it
# 183 CHNCXR_0314_0.png
# made it
# 184 CHNCXR_0221_0.png
# made it
# 185 CHNCXR_0387_1.png
# made it
# 186 CHNCXR_0385_1.png
# made it
# 187 CHNCXR_0576_1.png
# made it
# 188 CHNCXR_0212_0.png
# made it
# 189 CHNCXR_0085_0.png
# made it
# 190 CHNCXR_0175_0.png
# made it
# 191 CHNCXR_0400_1.png
# made it
# 192 CHNCXR_0375_1.png
# made it
# 193 CHNCXR_0315_0.png
# made it
# 194 CHNCXR_0169_0.png
# made it
# 195 CHNCXR_0462_1.png
# made it
# 196 CHNCXR_0651_1.png
# made it
# 197 CHNCXR_0264_0.png
# made it
# 198 CHNCXR_0502_1.png
# made it
# 199 CHNCXR_0466_1.png
# made it
# 200 CHNCXR_0172_0.png
# made it
# 201 CHNCXR_0130_0.png
# made it
# 202 CHNCXR_0464_1.png
# made it
# 203 CHNCXR_0168_0.png
# made it
# 204 CHNCXR_0223_0.png
# made it
# 205 CHNCXR_0359_1.png
# made it
# 206 CHNCXR_0006_0.png
# made it
# 207 CHNCXR_0320_0.png
# made it
# 208 CHNCXR_0523_1.png
# made it
# 209 CHNCXR_0259_0.png
# made it
# 210 CHNCXR_0344_1.png
# made it
# 211 CHNCXR_0107_0.png
# made it
# 212 CHNCXR_0620_1.png
# made it
# 213 CHNCXR_0095_0.png
# made it
# 214 CHNCXR_0317_0.png
# made it
# 215 CHNCXR_0152_0.png
# made it
# 216 CHNCXR_0411_1.png
# made it
# 217 CHNCXR_0660_1.png
# made it
# 218 CHNCXR_0521_1.png
# made it
# 219 CHNCXR_0567_1.png
# made it
# 220 CHNCXR_0364_1.png
# made it
# 221 CHNCXR_0124_0.png
# made it
# 222 CHNCXR_0076_0.png
# made it
# 223 CHNCXR_0507_1.png
# made it
# 224 CHNCXR_0373_1.png
# made it
# 225 CHNCXR_0165_0.png
# made it
# 226 CHNCXR_0346_1.png
# made it
# 227 CHNCXR_0186_0.png
# made it
# 228 CHNCXR_0161_0.png
# made it
# 229 CHNCXR_0230_0.png
# made it
# 230 CHNCXR_0509_1.png
# made it
# 231 CHNCXR_0485_1.png
# made it
# 232 CHNCXR_0335_1.png
# made it
# 233 CHNCXR_0115_0.png
# made it
# 234 CHNCXR_0153_0.png
# made it
# 235 CHNCXR_0630_1.png
# made it
# 236 CHNCXR_0260_0.png
# made it
# 237 CHNCXR_0433_1.png
# made it
# 238 CHNCXR_0094_0.png
# made it
# 239 CHNCXR_0075_0.png
# made it
# 240 CHNCXR_0490_1.png
# made it
# 241 CHNCXR_0382_1.png
# made it
# 242 CHNCXR_0516_1.png
# made it
# 243 CHNCXR_0122_0.png
# made it
# 244 CHNCXR_0547_1.png
# made it
# 245 CHNCXR_0463_1.png
# made it
# 246 CHNCXR_0639_1.png
# made it
# 247 CHNCXR_0624_1.png
# made it
# 248 CHNCXR_0435_1.png
# made it
# 249 CHNCXR_0319_0.png
# made it
# 250 CHNCXR_0653_1.png
# made it
# 251 CHNCXR_0308_0.png
# made it
# 252 CHNCXR_0018_0.png
# made it
# 253 CHNCXR_0647_1.png
# made it
# 254 CHNCXR_0139_0.png
# made it
# 255 CHNCXR_0594_1.png
# made it
# 256 CHNCXR_0293_0.png
# made it
# 257 CHNCXR_0520_1.png
# made it
# 258 CHNCXR_0099_0.png
# made it
# 259 CHNCXR_0298_0.png
# made it
# 260 CHNCXR_0199_0.png
# made it
# 261 CHNCXR_0598_1.png
# made it
# 262 CHNCXR_0384_1.png
# made it
# 263 CHNCXR_0496_1.png
# made it
# 264 CHNCXR_0045_0.png
# made it
# 265 CHNCXR_0515_1.png
# made it
# 266 CHNCXR_0110_0.png
# made it
# 267 CHNCXR_0493_1.png
# made it
# 268 CHNCXR_0646_1.png
# made it
# 269 CHNCXR_0038_0.png
# made it
# 270 CHNCXR_0477_1.png
# made it
# 271 CHNCXR_0267_0.png
# made it
# 272 CHNCXR_0059_0.png
# made it
# 273 CHNCXR_0381_1.png
# made it
# 274 CHNCXR_0143_0.png
# made it
# 275 CHNCXR_0328_1.png
# made it
# 276 CHNCXR_0445_1.png
# made it
# 277 CHNCXR_0621_1.png
# made it
# 278 CHNCXR_0167_0.png
# made it
# 279 CHNCXR_0542_1.png
# made it
# 280 CHNCXR_0171_0.png
# made it
# 281 CHNCXR_0352_1.png
# made it
# 282 CHNCXR_0068_0.png
# made it
# 283 CHNCXR_0461_1.png
# made it
# 284 CHNCXR_0243_0.png
# made it
# 285 CHNCXR_0288_0.png
# made it
# 286 CHNCXR_0648_1.png
# made it
# 287 CHNCXR_0412_1.png
# made it
# 288 CHNCXR_0144_0.png
# made it
# 289 CHNCXR_0657_1.png
# made it
# 290 CHNCXR_0568_1.png
# made it
# 291 CHNCXR_0007_0.png
# made it
# 292 CHNCXR_0177_0.png
# made it
# 293 CHNCXR_0118_0.png
# made it
# 294 CHNCXR_0478_1.png
# made it
# 295 CHNCXR_0556_1.png
# made it
# 296 CHNCXR_0189_0.png
# made it
# 297 CHNCXR_0604_1.png
# made it
# 298 CHNCXR_0451_1.png
# made it
# 299 CHNCXR_0157_0.png
# made it
# 300 CHNCXR_0533_1.png
# made it
# 301 CHNCXR_0127_0.png
# made it
# 302 CHNCXR_0282_0.png
# made it
# 303 CHNCXR_0548_1.png
# made it
# 304 CHNCXR_0348_1.png
# made it
# 305 CHNCXR_0583_1.png
# made it
# 306 CHNCXR_0206_0.png
# made it
# 307 CHNCXR_0539_1.png
# made it
# 308 CHNCXR_0558_1.png
# made it
# 309 CHNCXR_0297_0.png
# made it
# 310 CHNCXR_0325_0.png
# made it
# 311 CHNCXR_0343_1.png
# made it
# 312 CHNCXR_0501_1.png
# made it
# 313 CHNCXR_0188_0.png
# made it
# 314 CHNCXR_0300_0.png
# made it
# 315 CHNCXR_0399_1.png
# made it
# 316 CHNCXR_0492_1.png
# made it
# 317 CHNCXR_0072_0.png
# made it
# 318 CHNCXR_0123_0.png
# made it
# 319 CHNCXR_0643_1.png
# made it
# 320 CHNCXR_0121_0.png
# made it
# 321 CHNCXR_0544_1.png
# made it
# 322 CHNCXR_0043_0.png
# made it
# 323 CHNCXR_0536_1.png
# made it
# 324 CHNCXR_0249_0.png
# made it
# 325 CHNCXR_0225_0.png
# made it
# 326 CHNCXR_0126_0.png
# made it
# 327 CHNCXR_0438_1.png
# made it
# 328 CHNCXR_0289_0.png
# made it
# 329 CHNCXR_0579_1.png
# made it
# 330 CHNCXR_0638_1.png
# made it
# 331 CHNCXR_0355_1.png
# made it
# 332 CHNCXR_0635_1.png
# made it
# 333 CHNCXR_0303_0.png
# made it
# 334 CHNCXR_0574_1.png
# made it
# 335 CHNCXR_0626_1.png
# made it
# 336 CHNCXR_0231_0.png
# made it
# 337 CHNCXR_0532_1.png
# made it
# 338 CHNCXR_0027_0.png
# made it
# 339 CHNCXR_0137_0.png
# made it
# 340 CHNCXR_0418_1.png
# made it
# 341 CHNCXR_0605_1.png
# made it
# 342 CHNCXR_0316_0.png
# made it
# 343 CHNCXR_0074_0.png
# made it
# 344 CHNCXR_0103_0.png
# made it
# 345 CHNCXR_0294_0.png
# made it
# 346 CHNCXR_0424_1.png
# made it
# 347 CHNCXR_0441_1.png
# made it
# 348 CHNCXR_0341_1.png
# made it
# 349 CHNCXR_0505_1.png
# made it
# 350 CHNCXR_0013_0.png
# made it
# 351 CHNCXR_0017_0.png
# made it
# 352 CHNCXR_0468_1.png
# made it
# 353 CHNCXR_0307_0.png
# made it
# 354 CHNCXR_0205_0.png
# made it
# 355 CHNCXR_0622_1.png
# made it
# 356 CHNCXR_0215_0.png
# made it
# 357 CHNCXR_0417_1.png
# made it
# 358 CHNCXR_0273_0.png
# made it
# 359 CHNCXR_0266_0.png
# made it
# 360 CHNCXR_0360_1.png
# made it
# 361 CHNCXR_0562_1.png
# made it
# 362 CHNCXR_0156_0.png
# made it
# 363 CHNCXR_0518_1.png
# made it
# 364 CHNCXR_0550_1.png
# made it
# 365 CHNCXR_0589_1.png
# made it
# 366 CHNCXR_0421_1.png
# made it
# 367 CHNCXR_0487_1.png
# made it
# 368 CHNCXR_0048_0.png
# made it
# 369 CHNCXR_0305_0.png
# made it
# 370 CHNCXR_0347_1.png
# made it
# 371 CHNCXR_0369_1.png
# made it
# 372 CHNCXR_0036_0.png
# made it
# 373 CHNCXR_0370_1.png
# made it
# 374 CHNCXR_0002_0.png
# made it
# 375 CHNCXR_0202_0.png
# made it
# 376 CHNCXR_0057_0.png
# made it
# 377 CHNCXR_0488_1.png
# made it
# 378 CHNCXR_0531_1.png
# made it
# 379 CHNCXR_0146_0.png
# made it
# 380 CHNCXR_0602_1.png
# made it
# 381 CHNCXR_0318_0.png
# made it
# 382 CHNCXR_0330_1.png
# made it
# 383 CHNCXR_0148_0.png
# made it
# 384 CHNCXR_0067_0.png
# made it
# 385 CHNCXR_0650_1.png
# made it
# 386 CHNCXR_0323_0.png
# made it
# 387 CHNCXR_0522_1.png
# made it
# 388 CHNCXR_0306_0.png
# made it
# 389 CHNCXR_0623_1.png
# made it
# 390 CHNCXR_0258_0.png
# made it
# 391 CHNCXR_0362_1.png
# made it
# 392 CHNCXR_0543_1.png
# made it
# 393 CHNCXR_0080_0.png
# made it
# 394 CHNCXR_0476_1.png
# made it
# 395 CHNCXR_0194_0.png
# made it
# 396 CHNCXR_0456_1.png
# made it
# 397 CHNCXR_0327_1.png
# made it
# 398 CHNCXR_0636_1.png
# made it
# 399 CHNCXR_0025_0.png
# made it
# 400 CHNCXR_0207_0.png
# made it
# 401 CHNCXR_0495_1.png
# made it
# 402 CHNCXR_0590_1.png
# made it
# 403 CHNCXR_0609_1.png
# made it
# 404 CHNCXR_0150_0.png
# made it
# 405 CHNCXR_0222_0.png
# made it
# 406 CHNCXR_0419_1.png
# made it
# 407 CHNCXR_0050_0.png
# made it
# 408 CHNCXR_0326_0.png
# made it
# 409 CHNCXR_0549_1.png
# made it
# 410 CHNCXR_0179_0.png
# made it
# 411 CHNCXR_0216_0.png
# made it
# 412 CHNCXR_0284_0.png
# made it
# 413 CHNCXR_0631_1.png
# made it
# 414 CHNCXR_0022_0.png
# made it
# 415 CHNCXR_0585_1.png
# made it
# 416 CHNCXR_0310_0.png
# made it
# 417 CHNCXR_0155_0.png
# made it
# 418 CHNCXR_0497_1.png
# made it
# 419 CHNCXR_0654_1.png
# made it
# 420 CHNCXR_0088_0.png
# made it
# 421 CHNCXR_0498_1.png
# made it
# 422 CHNCXR_0584_1.png
# made it
# 423 CHNCXR_0026_0.png
# made it
# 424 CHNCXR_0386_1.png
# made it
# 425 CHNCXR_0379_1.png
# made it
# 426 CHNCXR_0406_1.png
# made it
# 427 CHNCXR_0336_1.png
# made it
# 428 CHNCXR_0219_0.png
# made it
# 429 CHNCXR_0569_1.png
# made it
# 430 CHNCXR_0208_0.png
# made it
# 431 CHNCXR_0081_0.png
# made it
# 432 CHNCXR_0437_1.png
# made it
# 433 CHNCXR_0500_1.png
# made it
# 434 CHNCXR_0051_0.png
# made it
# 435 CHNCXR_0641_1.png
# made it
# 436 CHNCXR_0564_1.png
# made it
# 437 CHNCXR_0117_0.png
# made it
# 438 CHNCXR_0656_1.png
# made it
# 439 CHNCXR_0227_0.png
# made it
# 440 CHNCXR_0082_0.png
# made it
# 441 CHNCXR_0271_0.png
# made it
# 442 CHNCXR_0020_0.png
# made it
# 443 CHNCXR_0162_0.png
# made it
# 444 CHNCXR_0614_1.png
# made it
# 445 CHNCXR_0413_1.png
# made it
# 446 CHNCXR_0554_1.png
# made it
# 447 CHNCXR_0633_1.png
# made it
# 448 CHNCXR_0324_0.png
# made it
# 449 CHNCXR_0039_0.png
# made it
# 450 CHNCXR_0342_1.png
# made it
# 451 CHNCXR_0447_1.png
# made it
# 452 CHNCXR_0203_0.png
# made it
# 453 CHNCXR_0248_0.png
# made it
# 454 CHNCXR_0503_1.png
# made it
# 455 CHNCXR_0083_0.png
# made it
# 456 CHNCXR_0244_0.png
# made it
# 457 CHNCXR_0242_0.png
# made it
# 458 CHNCXR_0408_1.png
# made it
# 459 CHNCXR_0301_0.png
# made it
# 460 CHNCXR_0140_0.png
# made it
# 461 CHNCXR_0116_0.png
# made it
# 462 CHNCXR_0053_0.png
# made it
# 463 CHNCXR_0275_0.png
# made it
# 464 CHNCXR_0606_1.png
# made it
# 465 CHNCXR_0332_1.png
# made it
# 466 CHNCXR_0530_1.png
# made it
# 467 CHNCXR_0429_1.png
# made it
# 468 CHNCXR_0104_0.png
# made it
# 469 CHNCXR_0537_1.png
# made it
# 470 CHNCXR_0649_1.png
# made it
# 471 CHNCXR_0555_1.png
# made it
# 472 CHNCXR_0416_1.png
# made it
# 473 CHNCXR_0658_1.png
# made it
# 474 CHNCXR_0339_1.png
# made it
# 475 CHNCXR_0034_0.png
# made it
# 476 CHNCXR_0407_1.png
# made it
# 477 CHNCXR_0309_0.png
# made it
# 478 CHNCXR_0233_0.png
# made it
# 479 CHNCXR_0652_1.png
# made it
# 480 CHNCXR_0128_0.png
# made it
# 481 CHNCXR_0448_1.png
# made it
# 482 CHNCXR_0201_0.png
# made it
# 483 CHNCXR_0032_0.png
# made it
# 484 CHNCXR_0486_1.png
# made it
# 485 CHNCXR_0535_1.png
# made it
# 486 CHNCXR_0628_1.png
# made it
# 487 CHNCXR_0029_0.png
# made it
# 488 CHNCXR_0160_0.png
# made it
# 489 CHNCXR_0213_0.png
# made it
# 490 CHNCXR_0087_0.png
# made it
# 491 CHNCXR_0023_0.png
# made it
# 492 CHNCXR_0353_1.png
# made it
# 493 CHNCXR_0430_1.png
# made it
# 494 CHNCXR_0056_0.png
# made it
# 495 CHNCXR_0640_1.png
# made it
# 496 CHNCXR_0185_0.png
# made it
# 497 CHNCXR_0129_0.png
# made it
# 498 CHNCXR_0354_1.png
# made it
# 499 CHNCXR_0166_0.png
# made it
# 500 CHNCXR_0452_1.png
# made it
# 501 CHNCXR_0195_0.png
# made it
# 502 CHNCXR_0659_1.png
# made it
# 503 CHNCXR_0573_1.png
# made it
# 504 CHNCXR_0263_0.png
# made it
# 505 CHNCXR_0645_1.png
# made it
# 506 CHNCXR_0575_1.png
# made it
# 507 CHNCXR_0136_0.png
# made it
# 508 CHNCXR_0280_0.png
# made it
# 509 CHNCXR_0009_0.png
# made it
# 510 CHNCXR_0279_0.png
# made it
# 511 CHNCXR_0105_0.png
# made it
# 512 CHNCXR_0525_1.png
# made it
# 513 CHNCXR_0388_1.png
# made it
# 514 CHNCXR_0054_0.png
# made it
# 515 CHNCXR_0295_0.png
# made it
# 516 CHNCXR_0220_0.png
# made it
# 517 CHNCXR_0292_0.png
# made it
# 518 CHNCXR_0281_0.png
# made it
# 519 CHNCXR_0396_1.png
# made it
# 520 CHNCXR_0446_1.png
# made it
# 521 CHNCXR_0277_0.png
# made it
# 522 CHNCXR_0170_0.png
# made it
# 523 CHNCXR_0228_0.png
# made it
# 524 CHNCXR_0582_1.png
# made it
# 525 CHNCXR_0079_0.png
# made it
# 526 CHNCXR_0566_1.png
# made it
# 527 CHNCXR_0291_0.png
# made it
# 528 CHNCXR_0349_1.png
# made it
# 529 CHNCXR_0365_1.png
# made it
# 530 CHNCXR_0077_0.png
# made it
# 531 CHNCXR_0593_1.png
# made it
# 532 CHNCXR_0154_0.png
# made it
# 533 CHNCXR_0472_1.png
# made it
# 534 CHNCXR_0426_1.png
# made it
# 535 CHNCXR_0232_0.png
# made it
# 536 CHNCXR_0145_0.png
# made it
# 537 CHNCXR_0184_0.png
# made it
# 538 CHNCXR_0469_1.png
# made it
# 539 CHNCXR_0262_0.png
# made it
# 540 CHNCXR_0055_0.png
# made it
# 541 CHNCXR_0415_1.png
# made it
# 542 CHNCXR_0552_1.png
# made it
# 543 CHNCXR_0191_0.png
# made it
# 544 CHNCXR_0363_1.png
# made it
# 545 CHNCXR_0253_0.png
# made it
# 546 CHNCXR_0119_0.png
# made it
# 547 CHNCXR_0135_0.png
# made it
# 548 CHNCXR_0559_1.png
# made it
# 549 CHNCXR_0519_1.png
# made it
# 550 CHNCXR_0356_1.png
# made it
# 551 CHNCXR_0380_1.png
# made it
# 552 CHNCXR_0482_1.png
# made it
# 553 CHNCXR_0634_1.png
# made it
# 554 CHNCXR_0350_1.png
# made it
# 555 CHNCXR_0033_0.png
# made it
# 556 CHNCXR_0475_1.png
# made it
# 557 CHNCXR_0372_1.png
# made it
# 558 CHNCXR_0304_0.png
# made it
# 559 CHNCXR_0268_0.png
# made it
# 560 CHNCXR_0376_1.png
# made it
# 561 CHNCXR_0483_1.png
# made it
# 562 CHNCXR_0008_0.png
# made it
# 563 CHNCXR_0196_0.png
# made it
# 564 CHNCXR_0004_0.png
# made it
# 565 CHNCXR_0030_0.png
# made it
# 566 CHNCXR_0337_1.png
# made it
# 567 CHNCXR_0615_1.png
# made it
# 568 CHNCXR_0510_1.png
# made it
# 569 CHNCXR_0178_0.png
# made it
# 570 CHNCXR_0111_0.png
# made it
# 571 CHNCXR_0204_0.png
# made it
# 572 CHNCXR_0247_0.png
# made it
# 573 CHNCXR_0457_1.png
# made it
# 574 CHNCXR_0141_0.png
# made it
# 575 CHNCXR_0274_0.png
# made it
# 576 CHNCXR_0226_0.png
# made it
# 577 CHNCXR_0211_0.png
# made it
# 578 CHNCXR_0163_0.png
# made it
# 579 CHNCXR_0198_0.png
# made it
# 580 CHNCXR_0182_0.png
# made it
# 581 CHNCXR_0113_0.png
# made it
# 582 CHNCXR_0133_0.png
# made it
# 583 CHNCXR_0361_1.png
# made it
# 584 CHNCXR_0016_0.png
# made it
# 585 CHNCXR_0180_0.png
# made it
# 586 CHNCXR_0287_0.png
# made it
# 587 CHNCXR_0235_0.png
# made it
# 588 CHNCXR_0608_1.png
# made it
# 589 CHNCXR_0402_1.png
# made it
# 590 CHNCXR_0434_1.png
# made it
# 591 CHNCXR_0131_0.png
# made it
# 592 CHNCXR_0511_1.png
# made it
# 593 CHNCXR_0595_1.png
# made it
# 594 CHNCXR_0187_0.png
# made it
# 595 CHNCXR_0587_1.png
# made it
# 596 CHNCXR_0591_1.png
# made it
# 597 CHNCXR_0480_1.png
# made it
# 598 CHNCXR_0035_0.png
# made it
# 599 CHNCXR_0401_1.png
# made it
# 600 CHNCXR_0283_0.png
# made it
# 601 CHNCXR_0192_0.png
# made it
# 602 CHNCXR_0312_0.png
# made it
# 603 CHNCXR_0238_0.png
# made it
# 604 CHNCXR_0241_0.png
# made it
# 605 CHNCXR_0164_0.png
# made it
# 606 CHNCXR_0246_0.png
# made it
# 607 CHNCXR_0563_1.png
# made it
# 608 CHNCXR_0453_1.png
# made it
# 609 CHNCXR_0534_1.png
# made it
# 610 CHNCXR_0265_0.png
# made it
# 611 CHNCXR_0471_1.png
# made it
# 612 CHNCXR_0389_1.png
# made it
# 613 CHNCXR_0512_1.png
# made it
# 614 CHNCXR_0037_0.png
# made it
# 615 CHNCXR_0560_1.png
# made it
# 616 CHNCXR_0432_1.png
# made it
# 617 CHNCXR_0524_1.png
# made it
# 618 CHNCXR_0597_1.png
# made it
# 619 CHNCXR_0473_1.png
# made it
# 620 CHNCXR_0449_1.png
# made it
# 621 CHNCXR_0214_0.png
# made it
# 622 CHNCXR_0261_0.png
# made it
# 623 CHNCXR_0357_1.png
# made it
# 624 CHNCXR_0101_0.png
# made it
# 625 CHNCXR_0629_1.png
# made it
# 626 CHNCXR_0047_0.png
# made it
# 627 CHNCXR_0484_1.png
# made it
# 628 CHNCXR_0403_1.png
# made it
# 629 CHNCXR_0592_1.png
# made it
# 630 CHNCXR_0112_0.png
# made it
# 631 CHNCXR_0149_0.png
# made it
# 632 CHNCXR_0042_0.png
# made it
# 633 CHNCXR_0489_1.png
# made it
# 634 CHNCXR_0311_0.png
# made it
# 635 CHNCXR_0070_0.png
# made it
# 636 CHNCXR_0345_1.png
# made it
# 637 CHNCXR_0290_0.png
# made it
# 638 CHNCXR_0459_1.png
# made it
# 639 CHNCXR_0313_0.png
# made it
# 640 CHNCXR_0655_1.png
# made it
# 641 CHNCXR_0391_1.png
# made it
# 642 CHNCXR_0132_0.png
# made it
# 643 CHNCXR_0545_1.png
# made it
# 644 CHNCXR_0611_1.png
# made it
# 645 CHNCXR_0254_0.png
# made it
# 646 CHNCXR_0405_1.png
# made it
# 647 CHNCXR_0224_0.png
# made it
# 648 CHNCXR_0181_0.png
# made it
# 649 CHNCXR_0239_0.png
# made it
# 650 CHNCXR_0442_1.png
# made it
# 651 CHNCXR_0444_1.png
# made it
# 652 CHNCXR_0084_0.png
# made it
# 653 CHNCXR_0540_1.png
# made it
# 654 CHNCXR_0108_0.png
# made it
# 655 CHNCXR_0557_1.png
# made it
# 656 CHNCXR_0494_1.png
# made it
# 657 CHNCXR_0481_1.png
# made it
# 658 CHNCXR_0114_0.png
# made it
# 659 CHNCXR_0514_1.png
# made it
# 660 CHNCXR_0428_1.png
# made it
# 661 CHNCXR_0019_0.png
# made it
