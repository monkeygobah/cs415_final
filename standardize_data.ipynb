# %% [markdown]
# # EDA and Cleaning
#
# ## Import data and clean it up.
#
# 1. resize everything to have the maximum height or width (depending on which one was larger over all of the data)
# 2. Make histograms of original size distribution
# 3. Add padding to make everything same size
# 4. Convert all images to greyscale

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
image_path = '../CXR_png/'

# %%
def make_histograms(list1, list2, label1='heights', label2='widths'):
    # Set up the figure and axes
    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))

    bin_num=3000
    # Plot the data
    axes[0].hist(list1, bins=bin_num, edgecolor="k", alpha=0.7)
    axes[1].set_title(f"Histogram of {label1}")
    axes[0].set_xlabel("Pixels")
    axes[0].set_ylabel("Frequency")

    axes[1].hist(list2, bins=bin_num, edgecolor="k", alpha=0.7)
    axes[1].set_title(f"Histogram of {label2}")
    axes[1].set_xlabel("Pixels")
    axes[1].set_ylabel("Frequency")

    # Adjust the layout
    plt.tight_layout()
    plt.show()
    

def get_lists_h_w(image_path):
    heights = []
    widths = []
    for root, dirs, files in os.walk(image_path):
        for file in files:
            if file.endswith('.png'):
                image = cv2.imread(os.path.join(root, file))
                heights.append(image.shape[0])
                widths.append(image.shape[1])
    return heights, widths

# %%
# max_height, max_width = get_max_h_w(image_path)
heights, widths = get_lists_h_w(image_path)
max_height = max(heights)
max_width = max(widths)

make_histograms(heights, widths)

# %%
import gc

# check to see if width or height is larger and what we are resizing based on 
resize_based_on_width = True if max_width > max_height else False

processed_image_path = 'clean_images'

# store scaled images in a dictionary using file path as key. Not very efficient but works well enough with memory management 
scaled_images_dict = {}

# resize based on aspect ratio
for root, dirs, files in os.walk(image_path):
    for file in files:
        if file.endswith('.png'):
            image = cv2.imread(os.path.join(root, file))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
            
            if resize_based_on_width:
                new_height = int((max_width / image.shape[1]) * image.shape[0])
                image = cv2.resize(image, (max_width, new_height))
            else:
                new_width = int((max_height / image.shape[0]) * image.shape[1])
                image = cv2.resize(image, (new_width, max_height))

            # update the max_width and max_height in case it changes after resize
            max_width = max(max_width, image.shape[1])
            max_height = max(max_height, image.shape[0])
            
            scaled_images_dict[file] = image

# %%
os.mkdir('./clean_images')
#  add padding based on the max_width and max_height after resizing
for file, image in scaled_images_dict.items():
    top_padding = (max_height - image.shape[0]) // 2
    bottom_padding = max_height - image.shape[0] - top_padding
    left_padding = (max_width - image.shape[1]) // 2
    right_padding = max_width - image.shape[1] - left_padding
    print(f"Processing {file}")
    print(f"Image dimensions: {image.shape[1]}x{image.shape[0]}")
    print(f"Max dimensions: {max_width}x{max_height}")
    print(f"Padding - Top: {top_padding}, Bottom: {bottom_padding}, Left: {left_padding}, Right: {right_padding}")
    
    padded_image = cv2.copyMakeBorder(image, top_padding, bottom_padding, left_padding, right_padding, cv2.BORDER_CONSTANT, value=[0, 0, 0])
    cv2.imwrite(os.path.join(processed_image_path, file), padded_image)

    # manage memory 
    del image, padded_image
    gc.collect()
# Out:
# Processing CHNCXR_0492_1.png
# Image dimensions: 2750x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 571, Right: 571
# Processing CHNCXR_0187_0.png
# Image dimensions: 2387x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left:
3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 622, Right: 623
# Processing CHNCXR_0321_0.png
# Image dimensions: 3048x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 422, Right: 422
# Processing CHNCXR_0570_1.png
# Image dimensions: 2559x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 666, Right: 667
# Processing CHNCXR_0535_1.png
# Image dimensions: 2766x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 563, Right: 563
# Processing CHNCXR_0020_0.png
# Image dimensions: 3241x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 325, Right: 326
# Processing CHNCXR_0065_0.png
# Image dimensions: 3052x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 420, Right: 420
# Processing CHNCXR_0411_1.png
# Image dimensions: 3051x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 420, Right: 421
# Processing CHNCXR_0454_1.png
# Image dimensions: 2693x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 599, Right: 600
# Processing CHNCXR_0379_1.png
# Image dimensions: 3184x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 354, Right: 354
# Processing CHNCXR_0141_0.png
# Image dimensions: 3075x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 408, Right: 409
# Processing CHNCXR_0104_0.png
# Image dimensions: 3002x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 445, Right: 445
# Processing CHNCXR_0384_1.png
# Image dimensions: 3058x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 417, Right: 417
# Processing CHNCXR_0240_0.png
# Image dimensions: 2993x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 449, Right: 450
# Processing CHNCXR_0205_0.png
# Image dimensions: 3042x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 425, Right: 425
# Processing CHNCXR_0648_1.png
# Image dimensions: 2654x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 619, Right: 619
# Processing CHNCXR_0318_0.png
# Image dimensions: 3067x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 412, Right: 413
# Processing CHNCXR_0549_1.png
# Image dimensions: 2906x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 493, Right: 493
# Processing CHNCXR_0019_0.png
# Image dimensions: 3061x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 415, Right: 416
# Processing CHNCXR_0574_1.png
# Image dimensions: 2617x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 637, Right: 638
# Processing CHNCXR_0531_1.png
# Image dimensions: 2985x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 453, Right: 454
# Processing CHNCXR_0024_0.png
# Image dimensions: 3050x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 421, Right: 421
# Processing CHNCXR_0061_0.png
# Image dimensions: 3046x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 423, Right: 423
# Processing CHNCXR_0630_1.png
# Image dimensions: 3013x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 439, Right: 440
# Processing CHNCXR_0325_0.png
# Image dimensions: 3059x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 416, Right: 417
# Processing CHNCXR_0589_1.png
# Image dimensions: 2746x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 573, Right: 573
# Processing CHNCXR_0181_0.png
# Image dimensions: 3065x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 413, Right: 414
# Processing CHNCXR_0238_0.png
# Image dimensions: 3050x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 421, Right: 421
# Processing CHNCXR_0494_1.png
# Image dimensions: 2573x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 659, Right: 660
# Processing CHNCXR_0280_0.png
# Image dimensions: 2846x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 523, Right: 523
# Processing CHNCXR_0469_1.png
# Image dimensions: 2469x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 711, Right: 712
# Processing CHNCXR_0139_0.png
# Image dimensions: 3071x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 410, Right: 411
# Processing CHNCXR_0344_1.png
# Image dimensions: 3017x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 437, Right: 438
# Processing CHNCXR_0301_0.png
# Image dimensions: 3052x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 420, Right: 420
# Processing CHNCXR_0651_1.png
# Image dimensions: 2800x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 546, Right: 546
# Processing CHNCXR_0614_1.png
# Image dimensions: 3087x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 402, Right: 403
# Processing CHNCXR_0045_0.png
# Image dimensions: 3061x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 415, Right: 416
# Processing CHNCXR_0550_1.png
# Image dimensions: 2750x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 571, Right: 571
# Processing CHNCXR_0515_1.png
# Image dimensions: 2496x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 698, Right: 698
# Processing CHNCXR_0158_0.png
# Image dimensions: 2743x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left:
3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 5, Right: 6
# Processing CHNCXR_0346_1.png
# Image dimensions: 2736x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 578, Right: 578
# Processing CHNCXR_0282_0.png
# Image dimensions: 3034x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 429, Right: 429
# Processing CHNCXR_0496_1.png
# Image dimensions: 2612x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 640, Right: 640
# Processing CHNCXR_0183_0.png
# Image dimensions: 3057x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 417, Right: 418
# Processing CHNCXR_0242_0.png
# Image dimensions: 3121x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 385, Right: 386
# Processing CHNCXR_0207_0.png
# Image dimensions: 2999x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 446, Right: 447
# Processing CHNCXR_0386_1.png
# Image dimensions: 3054x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 419, Right: 419
# Processing CHNCXR_0143_0.png
# Image dimensions: 2934x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 479, Right: 479
# Processing CHNCXR_0106_0.png
# Image dimensions: 3059x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 416, Right: 417
# Processing CHNCXR_0413_1.png
# Image dimensions: 2502x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 695, Right: 695
# Processing CHNCXR_0456_1.png
# Image dimensions: 2771x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 560, Right: 561
# Processing CHNCXR_0125_0.png
# Image dimensions: 2998x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 447, Right: 447
# Processing CHNCXR_0358_1.png
# Image dimensions: 2595x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 648, Right: 649
# Processing CHNCXR_0160_0.png
# Image dimensions: 2724x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 584, Right: 584
# Processing CHNCXR_0475_1.png
# Image dimensions: 2623x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 634, Right: 635
# Processing CHNCXR_0430_1.png
# Image dimensions: 3052x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 420, Right: 420
# Processing CHNCXR_0224_0.png
# Image dimensions: 3011x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 440, Right: 441
# Processing CHNCXR_0261_0.png
# Image dimensions: 3046x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 423, Right: 423
# Processing CHNCXR_0488_1.png
# Image dimensions: 2725x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 583, Right: 584
# Processing CHNCXR_0595_1.png
# Image dimensions: 2655x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 618, Right: 619
# Processing CHNCXR_0080_0.png
# Image dimensions: 3046x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 423, Right: 423
# Processing CHNCXR_0038_0.png
# Image dimensions: 2744x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 574, Right: 574
# Processing CHNCXR_0568_1.png
# Image dimensions: 2653x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 619, Right: 620
# Processing CHNCXR_0040_0.png
# Image dimensions: 3061x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 415, Right: 416
# Processing CHNCXR_0005_0.png
# Image dimensions: 3069x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 411, Right: 412
# Processing CHNCXR_0510_1.png
# Image dimensions: 2678x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 607, Right: 607
# Processing CHNCXR_0555_1.png
# Image dimensions: 2875x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 508, Right: 509
# Processing CHNCXR_0304_0.png
# Image dimensions: 3057x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 417, Right: 418
# Processing CHNCXR_0611_1.png
# Image dimensions: 2775x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 558, Right: 559
# Processing CHNCXR_0654_1.png
# Image dimensions: 2703x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 594, Right: 595
# Processing CHNCXR_0219_0.png
# Image dimensions: 3008x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 442, Right: 442
# Processing CHNCXR_0398_1.png
# Image dimensions: 2464x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 714, Right: 714
# Processing CHNCXR_0365_1.png
# Image dimensions: 2626x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 633, Right: 633
# Processing CHNCXR_0118_0.png
# Image dimensions: 2994x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 449, Right: 449
# Processing CHNCXR_0448_1.png
# Image dimensions: 2508x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 692, Right: 692
# Processing CHNCXR_0635_1.png
# Image dimensions: 2438x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 727, Right: 727
# Processing CHNCXR_0099_0.png
# Image dimensions: 2584x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 654, Right: 654
# Processing CHNCXR_0320_0.png
# Image dimensions: 3065x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 413, Right: 414
# Processing CHNCXR_0534_1.png
# Image dimensions: 2832x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 530, Right: 530
# Processing CHNCXR_0571_1.png
# Image dimensions: 2737x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 577, Right: 578
# Processing CHNCXR_0064_0.png
# Image dimensions: 3059x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 416, Right: 417
# Processing CHNCXR_0021_0.png
# Image dimensions: 2914x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 489, Right: 489
# Processing CHNCXR_0429_1.png
# Image dimensions: 3044x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 424, Right: 424
# Processing CHNCXR_0285_0.png
# Image dimensions: 3001x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 445, Right: 446
# Processing CHNCXR_0179_0.png
# Image dimensions: 3061x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 415, Right: 416
# Processing CHNCXR_0341_1.png
# Image dimensions: 3057x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 417, Right: 418
# Processing CHNCXR_0184_0.png
# Image dimensions: 3054x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 419, Right: 419
# Processing CHNCXR_0491_1.png
# Image dimensions: 2739x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 576, Right: 577
# Processing CHNCXR_0278_0.png
# Image dimensions: 2691x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 600, Right: 601
# Processing CHNCXR_0381_1.png
# Image dimensions: 3044x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 424, Right: 424
# Processing CHNCXR_0200_0.png
# Image dimensions: 3005x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 443, Right: 444
# Processing CHNCXR_0245_0.png
# Image dimensions: 2998x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 447, Right: 447
# Processing CHNCXR_0451_1.png
# Image dimensions: 2878x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 507, Right: 507
# Processing CHNCXR_0414_1.png
# Image dimensions: 2834x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 529, Right: 529
# Processing CHNCXR_0339_1.png
# Image dimensions: 3097x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 397, Right: 398
# Processing CHNCXR_0101_0.png
# Image dimensions: 3000x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 446, Right: 446
# Processing CHNCXR_0144_0.png
# Image dimensions: 2462x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 715, Right: 715
# Processing CHNCXR_0509_1.png
# Image dimensions: 2666x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 613, Right: 613
# Processing CHNCXR_0059_0.png
# Image dimensions: 3054x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 419, Right: 419
# Processing CHNCXR_0608_1.png
# Image dimensions: 3010x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 441, Right: 441
# Processing CHNCXR_0103_0.png
# Image dimensions: 2279x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 806, Right: 807
# Processing CHNCXR_0146_0.png
# Image dimensions: 3011x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 440, Right: 441
# Processing CHNCXR_0453_1.png
# Image dimensions: 3035x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 428, Right: 429
# Processing CHNCXR_0416_1.png
# Image dimensions: 2633x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 629, Right: 630
# Processing CHNCXR_0202_0.png
# Image dimensions: 3577x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 157, Right: 158
# Processing CHNCXR_0247_0.png
# Image dimensions: 3063x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 414, Right: 415
# Processing CHNCXR_0383_1.png
# Image dimensions: 3080x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 406, Right: 406
# Processing CHNCXR_0066_0.png
# Image dimensions: 3061x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 415, Right: 416
# Processing CHNCXR_0023_0.png
# Image dimensions: 3065x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 413, Right: 414
# Processing CHNCXR_0536_1.png
# Image dimensions: 2838x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 527, Right: 527
# Processing CHNCXR_0573_1.png
# Image dimensions: 2529x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 681, Right: 682
# Processing CHNCXR_0322_0.png
# Image dimensions: 3052x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 420, Right: 420
# Processing CHNCXR_0637_1.png
# Image dimensions: 2570x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 661, Right: 661
# Processing CHNCXR_0493_1.png
# Image dimensions: 2577x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 657, Right: 658
# Processing CHNCXR_0186_0.png
# Image dimensions: 2584x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 654, Right: 654
# Processing CHNCXR_0343_1.png
# Image dimensions: 2840x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 526, Right: 526
# Processing CHNCXR_0287_0.png
# Image dimensions: 2767x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 562, Right: 563
# Processing CHNCXR_0613_1.png
# Image dimensions: 2859x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 516, Right: 517
# Processing CHNCXR_0656_1.png
# Image dimensions: 3014x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 439, Right: 439
# Processing CHNCXR_0306_0.png
# Image dimensions: 3071x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 410, Right: 411
# Processing CHNCXR_0512_1.png
# Image dimensions: 3004x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 444, Right: 444
# Processing CHNCXR_0557_1.png
# Image dimensions: 2835x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 528, Right: 529
# Processing CHNCXR_0042_0.png
# Image dimensions: 3059x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 416, Right: 417
# Processing CHNCXR_0007_0.png
# Image dimensions: 2982x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 455, Right: 455
# Processing CHNCXR_0367_1.png
# Image dimensions: 2533x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 679, Right: 680
# Processing CHNCXR_0226_0.png
# Image dimensions: 2999x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 446, Right: 447
# Processing CHNCXR_0263_0.png
# Image dimensions: 3061x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 415, Right: 416
# Processing CHNCXR_0477_1.png
# Image dimensions: 2611x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 640, Right: 641
# Processing CHNCXR_0432_1.png
# Image dimensions: 3041x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 425, Right: 426
# Processing CHNCXR_0127_0.png
# Image dimensions: 3121x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 385, Right: 386
# Processing CHNCXR_0162_0.png
# Image dimensions: 3057x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 417, Right: 418
# Processing CHNCXR_0082_0.png
# Image dimensions: 3057x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 417, Right: 418
# Processing CHNCXR_0597_1.png
# Image dimensions: 3006x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 443, Right: 443
# Processing CHNCXR_0363_1.png
# Image dimensions: 2647x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 622, Right: 623
# Processing CHNCXR_0516_1.png
# Image dimensions: 2640x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 626, Right: 626
# Processing CHNCXR_0553_1.png
# Image dimensions: 2606x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 643, Right: 643
# Processing CHNCXR_0046_0.png
# Image dimensions: 3071x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 410, Right: 411
# Processing CHNCXR_0003_0.png
# Image dimensions: 3043x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 424, Right: 425
# Processing CHNCXR_0617_1.png
# Image dimensions: 2827x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 532, Right: 533
# Processing CHNCXR_0652_1.png
# Image dimensions: 2954x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 469, Right: 469
# Processing CHNCXR_0302_0.png
# Image dimensions: 2632x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 630, Right: 630
# Processing CHNCXR_0086_0.png
# Image dimensions: 3050x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 421, Right: 421
# Processing CHNCXR_0593_1.png
# Image dimensions: 2891x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 500, Right: 501
# Processing CHNCXR_0473_1.png
# Image dimensions: 2754x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 569, Right: 569
# Processing CHNCXR_0436_1.png
# Image dimensions: 2896x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 498, Right: 498
# Processing CHNCXR_0123_0.png
# Image dimensions: 3057x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 417, Right: 418
# Processing CHNCXR_0166_0.png
# Image dimensions: 2901x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 495, Right: 496
# Processing CHNCXR_0222_0.png
# Image dimensions: 2991x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 450, Right: 451
# Processing CHNCXR_0267_0.png
# Image dimensions: 3079x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 406, Right: 407
# Processing CHNCXR_0206_0.png
# Image dimensions: 3383x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 254, Right: 255
# Processing CHNCXR_0243_0.png
# Image dimensions: 3063x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 414, Right: 415
# Processing CHNCXR_0387_1.png
# Image dimensions: 2900x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 496, Right: 496
# Processing CHNCXR_0107_0.png
# Image dimensions: 3191x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 350, Right: 351
# Processing CHNCXR_0142_0.png
# Image dimensions: 3024x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 434, Right: 434
# Processing CHNCXR_0457_1.png
# Image dimensions: 2789x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 551, Right: 552
# Processing CHNCXR_0412_1.png
# Image dimensions: 3051x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 420, Right: 421
# Processing CHNCXR_0347_1.png
# Image dimensions: 2756x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 568, Right: 568
# Processing CHNCXR_0283_0.png
# Image dimensions: 3008x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 442, Right: 442
# Processing CHNCXR_0497_1.png
# Image dimensions: 2659x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 616, Right: 617
# Processing CHNCXR_0182_0.png
# Image dimensions: 3077x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 407, Right: 408
# Processing CHNCXR_0326_0.png
# Image dimensions: 3063x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 414, Right: 415
# Processing CHNCXR_0633_1.png
# Image dimensions: 3092x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 400, Right: 400
# Processing CHNCXR_0062_0.png
# Image dimensions: 3059x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 416, Right: 417
# Processing CHNCXR_0027_0.png
# Image dimensions: 3074x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 409, Right: 409
# Processing CHNCXR_0532_1.png
# Image dimensions: 3209x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 341, Right: 342
# Processing CHNCXR_0577_1.png
# Image dimensions: 3085x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 403, Right: 404
# Processing CHNCXR_0180_0.png
# Image dimensions: 3660x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 116, Right: 116
# Processing CHNCXR_0495_1.png
# Image dimensions: 2845x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 523, Right: 524
# Processing CHNCXR_0239_0.png
# Image dimensions: 2996x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 448, Right: 448
# Processing CHNCXR_0468_1.png
# Image dimensions: 2723x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 584, Right: 585
# Processing CHNCXR_0281_0.png
# Image dimensions: 3057x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 417, Right: 418
# Processing CHNCXR_0345_1.png
# Image dimensions: 2838x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 527, Right: 527
# Processing CHNCXR_0138_0.png
# Image dimensions: 3059x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 416, Right: 417
# Processing CHNCXR_0530_1.png
# Image dimensions: 2939x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 476, Right: 477
# Processing CHNCXR_0575_1.png
# Image dimensions: 2988x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 452, Right: 452
# Processing CHNCXR_0060_0.png
# Image dimensions: 3071x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 410, Right: 411
# Processing CHNCXR_0025_0.png
# Image dimensions: 3065x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 413, Right: 414
# Processing CHNCXR_0631_1.png
# Image dimensions: 2669x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 611, Right: 612
# Processing CHNCXR_0588_1.png
# Image dimensions: 2748x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 572, Right: 572
# Processing CHNCXR_0324_0.png
# Image dimensions: 3057x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 417, Right: 418
# Processing CHNCXR_0649_1.png
# Image dimensions: 3036x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 428, Right: 428
# Processing CHNCXR_0319_0.png
# Image dimensions: 3052x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 420, Right: 420
# Processing CHNCXR_0548_1.png
# Image dimensions: 3054x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 419, Right: 419
# Processing CHNCXR_0018_0.png
# Image dimensions: 3087x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 402, Right: 403
# Processing CHNCXR_0455_1.png
# Image dimensions: 3027x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 432, Right: 433
# Processing CHNCXR_0410_1.png
# Image dimensions: 2838x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 527, Right: 527
# Processing CHNCXR_0105_0.png
# Image dimensions: 2613x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 639, Right: 640
# Processing CHNCXR_0378_1.png
# Image dimensions: 3025x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 433, Right: 434
# Processing CHNCXR_0140_0.png
# Image dimensions: 3234x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 329, Right: 329
# Processing CHNCXR_0385_1.png
# Image dimensions: 2855x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 518, Right: 519
# Processing CHNCXR_0204_0.png
# Image dimensions: 2997x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 447, Right: 448
# Processing CHNCXR_0241_0.png
# Image dimensions: 2975x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 458, Right: 459
# Processing CHNCXR_0079_0.png
# Image dimensions: 3059x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 416, Right: 417
# Processing CHNCXR_0529_1.png
# Image dimensions: 2893x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 499, Right: 500
# Processing CHNCXR_0591_1.png
# Image dimensions: 3025x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 433, Right: 434
# Processing CHNCXR_0084_0.png
# Image dimensions: 2792x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 550, Right: 550
# Processing CHNCXR_0628_1.png
# Image dimensions: 3015x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 438, Right: 439
# Processing CHNCXR_0220_0.png
# Image dimensions: 2976x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 458, Right: 458
# Processing CHNCXR_0265_0.png
# Image dimensions: 2634x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 629, Right: 629
# Processing CHNCXR_0199_0.png
# Image dimensions: 2948x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 472, Right: 472
# Processing CHNCXR_0121_0.png
# Image dimensions: 2761x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 565, Right: 566
# Processing CHNCXR_0164_0.png
# Image dimensions: 3063x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 414, Right: 415
# Processing CHNCXR_0298_0.png
# Image dimensions: 3054x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 419, Right: 419
# Processing CHNCXR_0471_1.png
# Image dimensions: 2604x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 644, Right: 644
# Processing CHNCXR_0434_1.png
# Image dimensions: 3030x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 431, Right: 431
# Processing CHNCXR_0159_0.png
# Image dimensions: 3003x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 444, Right: 445
# Processing CHNCXR_0361_1.png
# Image dimensions: 2951x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 470, Right: 471
# Processing CHNCXR_0409_1.png
# Image dimensions: 2817x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 537, Right: 538
# Processing CHNCXR_0258_0.png
# Image dimensions: 3056x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 418, Right: 418
# Processing CHNCXR_0300_0.png
# Image dimensions: 3050x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 421, Right: 421
# Processing CHNCXR_0615_1.png
# Image dimensions: 2623x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 634, Right: 635
# Processing CHNCXR_0650_1.png
# Image dimensions: 2687x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 602, Right: 603
# Processing CHNCXR_0044_0.png
# Image dimensions: 3001x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 445, Right: 446
# Processing CHNCXR_0001_0.png
# Image dimensions: 3084x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 404, Right: 404
# Processing CHNCXR_0514_1.png
# Image dimensions: 2869x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 511, Right: 512
# Processing CHNCXR_0551_1.png
# Image dimensions: 2848x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 522, Right: 522
# Processing CHNCXR_0405_1.png
# Image dimensions: 2884x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 504, Right: 504
# Processing CHNCXR_0440_1.png
# Image dimensions: 2789x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 551, Right: 552
# Processing CHNCXR_0155_0.png
# Image dimensions: 3892x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 0, Right: 0
# Processing CHNCXR_0328_1.png
# Image dimensions: 3047x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 422, Right: 423
# Processing CHNCXR_0110_0.png
# Image dimensions: 2765x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 563, Right: 564
# Processing CHNCXR_0390_1.png
# Image dimensions: 2871x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 510, Right: 511
# Processing CHNCXR_0254_0.png
# Image dimensions: 3035x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 428, Right: 429
# Processing CHNCXR_0211_0.png
# Image dimensions: 2994x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 449, Right: 449
# Processing CHNCXR_0619_1.png
# Image dimensions: 2820x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 536, Right: 536
# Processing CHNCXR_0518_1.png
# Image dimensions: 2655x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 618, Right: 619
# Processing CHNCXR_0048_0.png
# Image dimensions: 3052x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 420, Right: 420
# Processing CHNCXR_0560_1.png
# Image dimensions: 2756x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 568, Right: 568
# Processing CHNCXR_0525_1.png
# Image dimensions: 2626x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 633, Right: 633
# Processing CHNCXR_0030_0.png
# Image dimensions: 2874x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 509, Right: 509
# Processing CHNCXR_0075_0.png
# Image dimensions: 3333x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 279, Right: 280
# Processing CHNCXR_0661_1.png
# Image dimensions: 2870x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 511, Right: 511
# Processing CHNCXR_0088_0.png
# Image dimensions: 2832x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 530, Right: 530
# Processing CHNCXR_0624_1.png
# Image dimensions: 2948x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 472, Right: 472
# Processing CHNCXR_0195_0.png
# Image dimensions: 2997x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 447, Right: 448
# Processing CHNCXR_0269_0.png
# Image dimensions: 2967x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 462, Right: 463
# Processing CHNCXR_0480_1.png
# Image dimensions: 2881x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 505, Right: 506
# Processing CHNCXR_0294_0.png
# Image dimensions: 3057x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 417, Right: 418
# Processing CHNCXR_0438_1.png
# Image dimensions: 3250x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 321, Right: 321
# Processing CHNCXR_0168_0.png
# Image dimensions: 3071x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 410, Right: 411
# Processing CHNCXR_0350_1.png
# Image dimensions: 2883x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 504, Right: 505
# Processing CHNCXR_0315_0.png
# Image dimensions: 3016x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 438, Right: 438
# Processing CHNCXR_0645_1.png
# Image dimensions: 2656x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 618, Right: 618
# Processing CHNCXR_0600_1.png
# Image dimensions: 3149x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 371, Right: 372
# Processing CHNCXR_0014_0.png
# Image dimensions: 3084x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 404, Right: 404
# Processing CHNCXR_0051_0.png
# Image dimensions: 3052x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 420, Right: 420
# Processing CHNCXR_0544_1.png
# Image dimensions: 2736x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 578, Right: 578
# Processing CHNCXR_0501_1.png
# Image dimensions: 2486x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 703, Right: 703
# Processing CHNCXR_0109_0.png
# Image dimensions: 2416x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 738, Right: 738
# Processing CHNCXR_0331_1.png
# Image dimensions: 3028x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 432, Right: 432
# Processing CHNCXR_0374_1.png
# Image dimensions: 3075x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 408, Right: 409
# Processing CHNCXR_0459_1.png
# Image dimensions: 2520x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 686, Right: 686
# Processing CHNCXR_0208_0.png
# Image dimensions: 2767x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 562, Right: 563
# Processing CHNCXR_0389_1.png
# Image dimensions: 2763x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 564, Right: 565
# Processing CHNCXR_0499_1.png
# Image dimensions: 2960x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 466, Right: 466
# Processing CHNCXR_0270_0.png
# Image dimensions: 2999x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 446, Right: 447
# Processing CHNCXR_0235_0.png
# Image dimensions: 2874x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 509, Right: 509
# Processing CHNCXR_0349_1.png
# Image dimensions: 3052x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 420, Right: 420
# Processing CHNCXR_0171_0.png
# Image dimensions: 3001x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 445, Right: 446
# Processing CHNCXR_0134_0.png
# Image dimensions: 2530x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 681, Right: 681
# Processing CHNCXR_0421_1.png
# Image dimensions: 3006x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 443, Right: 443
# Processing CHNCXR_0464_1.png
# Image dimensions: 2807x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 542, Right: 543
# Processing CHNCXR_0029_0.png
# Image dimensions: 3067x3001
# Max dimensions: 3892x3001
# Padding - Top: 0, Bottom: 0, Left: 412, Right: 413

# %%
unique_shapes = set()

for root, dirs, files in os.walk(processed_image_path):
    for file in files:
        if file.endswith('.png'):
            image_path = os.path.join(root, file)
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
            unique_shapes.add(image.shape)

print(f"Unique shapes found: {unique_shapes}")
# Out:
# Unique shapes found: set()
